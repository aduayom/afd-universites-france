# %% [markdown]
# <br>
#
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Réalisé par :</strong>ADUAYOM MESSAN Daniel
# </div>
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Date :</strong> Octobre 2024
# </div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:darkgreen">ANALYSES ET CONNAISSANCE CLIENT</span></div><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:28px;color:#e60000">Clustering: Mise en place de modèles pour identifier le profil des acheteurs et groupe distinct</span></div><br><br>
# <hr>
#
# <br>
#
# <hr style="border-width:4px;border-color:#75DFC1">
# <center><h1>Analyse de données CRM</h1></center>
# <hr style="border-width:4px;border-color:#75DFC1">
#
# >Une base de données CRM (Customer Relationship Management) est une collection organisée de données relatives aux interactions et aux comportements des clients d'une entreprise. Ces bases de données contiennent souvent des informations sur les transactions, les préférences d'achat, les interactions avec l'entreprise (par le biais de différents canaux, tels que les e-mails, les appels téléphoniques, les achats en ligne et en magasin), et parfois des données sociodémographiques comme l'âge, le sexe, ou la localisation.
#
# >L'objectif principal d'une base de données CRM est de centraliser toutes ces informations afin d'améliorer la gestion des relations avec les clients et de soutenir la prise de décision dans le cadre des actions marketing, des ventes, du service client et de la fidélisation.
#
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🔍 Cadres d'utilisation d'une base de données CRM</h2>
# > Les bases de données CRM sont utilisées dans divers contextes au sein des entreprises pour :
#
# > 1. **Segmentation des clients :** Diviser la base de clients en groupes homogènes selon des critères tels que la fréquence d'achat, le montant des dépenses ou les catégories de produits achetées. Cela permet d'adapter les actions marketing à des segments spécifiques (ex : clients VIP, nouveaux clients, clients dormants).
#
# > 2. **Analyse de la valeur client (CLV) :** Estimer la valeur future des clients, souvent basée sur leur historique d'achats, afin de prioriser les efforts de marketing et de fidélisation.
#
# > 3. **Personnalisation des offres :** Utiliser les données CRM pour proposer des offres et recommandations adaptées aux préférences et aux comportements individuels des clients, augmentant ainsi l'engagement et les taux de conversion.
#
# > 4. **Prédiction du churn :** Identifier les clients susceptibles de quitter l'entreprise (churn) en analysant les tendances d'interaction et d'achat, permettant d'intervenir avant qu'ils ne partent.
#
# > 5. **Optimisation des campagnes marketing :** Planifier et exécuter des campagnes marketing ciblées en fonction des préférences des clients ou de leur engagement passé, avec des promotions adaptées pour chaque segment.
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🎯 Objectifs Clés du Projet</h2>
# > Dans notre projet, nous allons nous concentrer sur une approche de ciblage et de segmentation basée sur les données CRM disponibles. Notre objectif principal est d'identifier des groupes distincts au sein de la base de données clients et de comprendre les caractéristiques qui les différencient.
#
# >1. **Identification des segments de clients :** Nous allons utiliser des méthodes de segmentation, telles que le clustering, pour déterminer s'il existe des groupes homogènes au sein de notre base de données. Ces segments pourraient représenter différents types de clients avec des comportements ou des caractéristiques similaires.
#
# >2. **Analyse des caractéristiques des segments :** Une fois les segments identifiés, nous allons chercher à comprendre ce qui distingue chaque groupe. Par exemple, certains segments pourraient regrouper des clients à forte valeur, tandis que d'autres incluraient des clients qui privilégient un canal d'achat spécifique.
#
# >3. **Analyse statistique préalable :** Avant de procéder à la segmentation, nous allons vérifier si le clustering est approprié pour notre jeu de données. Pour ce faire, nous utiliserons des tests statistiques tels que les tests d'homogénéité, la distribution des variables, et l'analyse des tendances. Ces tests nous indiqueront si les données présentent des tendances naturelles de regroupement qui justifieraient l'utilisation d'algorithmes de clustering.
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">💡 Conclusion</h2>
# >
# >Ce projet vise à explorer la base de données CRM pour comprendre et segmenter les clients de manière plus précise. La segmentation nous permettra non seulement de mieux cibler les efforts de marketing, mais aussi de personnaliser les interactions avec les clients en fonction de leurs préférences et comportements. Cependant, la faisabilité de cette segmentation dépendra de la structure des données et de la présence de tendances naturelles de regroupemen
# >
# <br/><br/><br/>

# %% [markdown]
# <hr style="border-width:4px;border-color:#75DFC1">
# <center><h1>Analyse de données CRM</h1></center>
# <hr style="border-width:4px;border-color:#75DFC1">
#
# >Une base de données CRM (Customer Relationship Management) est une collection organisée de données relatives aux interactions et aux comportements des clients d'une entreprise. Ces bases de données contiennent souvent des informations sur les transactions, les préférences d'achat, les interactions avec l'entreprise (par le biais de différents canaux, tels que les e-mails, les appels téléphoniques, les achats en ligne et en magasin), et parfois des données sociodémographiques comme l'âge, le sexe, ou la localisation.
#
# >L'objectif principal d'une base de données CRM est de centraliser toutes ces informations afin d'améliorer la gestion des relations avec les clients et de soutenir la prise de décision dans le cadre des actions marketing, des ventes, du service client et de la fidélisation.
#
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🔍 Cadres d'utilisation d'une base de données CRM</h2>
# > Les bases de données CRM sont utilisées dans divers contextes au sein des entreprises pour :
#
# > 1. **Segmentation des clients :** Diviser la base de clients en groupes homogènes selon des critères tels que la fréquence d'achat, le montant des dépenses ou les catégories de produits achetées. Cela permet d'adapter les actions marketing à des segments spécifiques (ex : clients VIP, nouveaux clients, clients dormants).
#
# > 2. **Analyse de la valeur client (CLV) :** Estimer la valeur future des clients, souvent basée sur leur historique d'achats, afin de prioriser les efforts de marketing et de fidélisation.
#
# > 3. **Personnalisation des offres :** Utiliser les données CRM pour proposer des offres et recommandations adaptées aux préférences et aux comportements individuels des clients, augmentant ainsi l'engagement et les taux de conversion.
#
# > 4. **Prédiction du churn :** Identifier les clients susceptibles de quitter l'entreprise (churn) en analysant les tendances d'interaction et d'achat, permettant d'intervenir avant qu'ils ne partent.
#
# > 5. **Optimisation des campagnes marketing :** Planifier et exécuter des campagnes marketing ciblées en fonction des préférences des clients ou de leur engagement passé, avec des promotions adaptées pour chaque segment.
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🎯 Objectifs Clés du Projet</h2>
# > Dans notre projet, nous allons nous concentrer sur une approche de ciblage et de segmentation basée sur les données CRM disponibles. Notre objectif principal est d'identifier des groupes distincts au sein de la base de données clients et de comprendre les caractéristiques qui les différencient.
#
# >1. **Identification des segments de clients :** Nous allons utiliser des méthodes de segmentation, telles que le clustering, pour déterminer s'il existe des groupes homogènes au sein de notre base de données. Ces segments pourraient représenter différents types de clients avec des comportements ou des caractéristiques similaires.
#
# >2. **Analyse des caractéristiques des segments :** Une fois les segments identifiés, nous allons chercher à comprendre ce qui distingue chaque groupe. Par exemple, certains segments pourraient regrouper des clients à forte valeur, tandis que d'autres incluraient des clients qui privilégient un canal d'achat spécifique.
#
# >3. **Analyse statistique préalable :** Avant de procéder à la segmentation, nous allons vérifier si le clustering est approprié pour notre jeu de données. Pour ce faire, nous utiliserons des tests statistiques tels que les tests d'homogénéité, la distribution des variables, et l'analyse des tendances. Ces tests nous indiqueront si les données présentent des tendances naturelles de regroupement qui justifieraient l'utilisation d'algorithmes de clustering.
#
# >
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">💡 Conclusion</h2>
# >
# >Ce projet vise à explorer la base de données CRM pour comprendre et segmenter les clients de manière plus précise. La segmentation nous permettra non seulement de mieux cibler les efforts de marketing, mais aussi de personnaliser les interactions avec les clients en fonction de leurs préférences et comportements. Cependant, la faisabilité de cette segmentation dépendra de la structure des données et de la présence de tendances naturelles de regroupemen
# >
# <br/><br/><br/>

# %% [markdown]
# <br/>
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Présentation de la Base de Données FLO CRM</h1></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette section présente les variables de la base de données utilisée pour notre analyse, disponible <a href="https://www.kaggle.com/datasets/ramzanzdemir/flo-data-20k">ici</a>. Chaque variable est brièvement décrite afin de mieux comprendre sa signification et son rôle dans l'analyse de segmentation et de ciblage de la clientèle.
# </p>
#
# <ul style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>master_id :</strong> Numéro d'identification unique pour chaque client.</li>
#     <li><strong>order_channel :</strong> La plateforme utilisée par le client pour ses achats (Android, iOS, Desktop, Mobile, Offline).</li>
#     <li><strong>last_order_channel :</strong> Le canal où le dernier achat du client a été réalisé.</li>
#     <li><strong>first_order_date :</strong> La date à laquelle le client a effectué son premier achat.</li>
#     <li><strong>last_order_date :</strong> La date du dernier achat effectué par le client.</li>
#     <li><strong>last_order_date_online :</strong> La date du dernier achat réalisé en ligne par le client.</li>
#     <li><strong>last_order_date_offline :</strong> La date du dernier achat réalisé hors ligne par le client.</li>
#     <li><strong>order_num_total_ever_online :</strong> Nombre total d'achats effectués en ligne par le client.</li>
#     <li><strong>order_num_total_ever_offline :</strong> Nombre total d'achats effectués hors ligne par le client.</li>
#     <li><strong>customer_value_total_ever_offline :</strong> Montant total dépensé par le client pour ses achats hors ligne.</li>
#     <li><strong>customer_value_total_ever_online :</strong> Montant total dépensé par le client pour ses achats en ligne.</li>
#     <li><strong>interested_in_categories_12 :</strong> Liste des catégories de produits dans lesquelles le client a effectué des achats au cours des 12 derniers mois.</li>
# </ul>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     L'objectif de cette base de données est d'aider FLO à mieux comprendre ses clients, à identifier des segments distincts et à planifier des actions de marketing ciblées pour optimiser les ventes et la fidélisation.
# </p>

# %%
# Les bibliothèques qu'on va utiliser
import numpy as np 
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br/>
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Exploration de la Base de Données</h1></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     L'exploration de la base de données est une étape essentielle de notre projet. C'est le moment où nous prenons connaissance en détail des données avec lesquelles nous allons travailler. Cette phase comprend plusieurs actions importantes :
# </p>
#
# <ul style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Examen de la Structure des Données :</strong> Nous commençons par observer la structure globale de la base de données. Cela inclut le nombre de lignes et de colonnes, ainsi que les types de données présents.</li>
#     <li><strong>Identification des Valeurs Manquantes :</strong> Nous cherchons à identifier les éventuelles valeurs manquantes dans les données, ce qui est crucial pour la qualité de notre analyse.</li>
#     <li><strong>Renommage des Variables :</strong> Pour faciliter la compréhension et le traitement des données, nous avons renommé les variables en français. Cette étape rend chaque variable plus claire et plus accessible.</li>
#     <li><strong>Analyse Descriptive :</strong> Nous effectuons une analyse descriptive des différentes variables. Cela implique de calculer des statistiques de base comme la moyenne, la médiane, les écarts-types, etc.</li>
# </ul>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette exploration initiale nous permet de mieux comprendre les données et de préparer le terrain pour les analyses plus complexes à venir.
# </p>

# %%
# Lecture de la base de données 
Data_CRM = pd.read_csv("Data/flo_data_20k.csv", delimiter=",")
# Conversion des colonnes au format date
Data_CRM[['first_order_date', 'last_order_date', 'last_order_date_online','last_order_date_offline']] = Data_CRM[['first_order_date', 'last_order_date', 'last_order_date_online','last_order_date_offline']].apply(pd.to_datetime, format='%Y-%m-%d')

print("Affichage des 5 premières lignes")
display(Data_CRM.head())

print("Statistique descriptive")
display(Data_CRM.describe())

print("Dimensions de notre base de données")
display((Data_CRM.shape))
# Out:
# Affichage des 5 premières lignes
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                          4.0
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Taille de la Base de Données</h3>
#     <p>
#         Après examen de notre base de données, nous avons constaté qu'elle contient <strong>19945 lignes</strong> et <strong>12 colonnes</strong>. Cette taille indique que nous disposons d'un ensemble de données conséquent pour notre analyse, offrant une variété d'informations sur les clients et leurs interactions.
#     </p>
#     <p>
#         La présence de nombreuses colonnes suggère une richesse en termes de variables disponibles, permettant une exploration approfondie des caractéristiques des clients.
#     </p>
# </div>

# %%
# Affichage de la taille du Data_Campagne_cleanFrame
nombre_lignes = Data_CRM.shape[0]
nombre_colonnes = Data_CRM.shape[1]
print(f"La base de données contient {nombre_lignes} lignes et {nombre_colonnes} colonnes.")
# Out:
# La base de données contient 19945 lignes et 12 colonnes.

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Examen de la Structure des Données</h3>
#     <p>
#         L'examen de la structure de la base de données <em>Data_CRM</em> indique principalement des données numériques (float64) et des chaînes de caractères (object). Cette étape clé nous oriente sur le traitement et l'analyse de chaque variable.
#     </p>
# </div>

# %%
# Examen de la structure des données
structure_info = Data_CRM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Vérification Visuelle des Valeurs Manquantes</h3>
#     <p>
#         Nous avons créé une carte de chaleur pour visualiser les valeurs manquantes dans notre base de données. Cette méthode permet d'identifier rapidement les colonnes et les rangées qui contiennent des données incomplètes. Les zones jaunes sur la carte représentent les valeurs manquantes, nous aidant à comprendre l'étendue et la distribution des données manquantes dans l'ensemble de données.
#     </p>
# </div>

# %%
# Vérification visuelle des valeurs manquantes
plt.figure(figsize=(10, 6))
sns.heatmap(Data_CRM.isnull(), cbar=False, cmap='viridis')
plt.title('Carte de Chaleur des Valeurs Manquantes')
plt.xlabel('Colonnes')
plt.ylabel('Index des Entrées')
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Commentaire sur les valeurs manquantes</h3>
#     <p>
#        Nous pouvons constater que notre base de données est assez complète, sans aucune valeur manquante parmi les différentes variables. Cependant, nous sommes dans un environnement qui ne reflète pas toujours la réalité, car disposer de toutes les informations complètes dans une base de données CRM est généralement difficile. Nous partons du principe que notre base de données a été consolidée par le passé et que les traitements nécessaires ont déjà été effectués pour faciliter les utilisations futures.
#     </p>
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Visualisation des Variables - Analyses Univariée et Bivariée</h3>
#     <p>
#         Dans cette partie, nous allons explorer visuellement nos données. L'analyse univariée nous permet de comprendre chaque variable individuellement, tandis que l'analyse bivariée met en lumière les relations et corrélations entre deux variables. Ces visualisations nous aideront à saisir les tendances, les anomalies et les motifs dans notre jeu de données.
#     </p>
#     <p>
#         Nous utiliserons des graphiques clairs et informatifs, avec des légendes et des annotations pour faciliter la compréhension des résultats.
#     </p>
# </div>

# %%
Data_CRM.columns
# Out:
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12'],
#       dtype='object')

# %%
# Utilisation d'un contexte de style Seaborn temporaire pour cette cellule uniquement
with sns.axes_style("whitegrid"):
    # Création d'une figure avec 2 sous-graphiques (1 ligne, 2 colonnes)
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # 1 ligne, 2 colonnes

    # Liste des colonnes à visualiser
    colonnes = ['order_channel', 'last_order_channel']

    # Parcours des colonnes et création des histogrammes triés
    for i, col in enumerate(colonnes):
        ax = axes[i]  # Utiliser l'axe correspondant
        
        # Calculer les valeurs de fréquence triées pour chaque colonne
        sorted_order = Data_CRM[col].value_counts().index
        
        total = float(len(Data_CRM[col]))
        
        # Tracer les courbes avec les catégories triées
        sns.countplot(x=col, data=Data_CRM, palette="viridis", order=sorted_order, ax=ax)
        ax.set_title(f'Distribution de {col}')
        
        # Ajout des pourcentages sur les barres
        for p in ax.patches:
            height = p.get_height()
            ax.text(p.get_x() + p.get_width()/2.,
                    height + 3,
                    '{:1.2f}%'.format(100 * height / total),
                    ha="center")

    # Ajustement de l'espace entre les graphiques
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Distributions des Variables</h3>
#     <p><strong>Order_channel :</strong> Nous observons que le principal canal d'achat des clients est l'application Android, représentant 47,61 % des achats. Ensuite, nous avons les applications Mobile et iOS, qui complètent ce trio. Ces trois canaux sont associés au domaine mobile, car les systèmes Android et iOS sont utilisés sur des appareils téléphoniques. Enfin, le canal Desktop se démarque également, représentant 13,7 % des achats. Cela souligne que bien que les clients privilégient les plateformes mobiles, le canal Desktop reste un choix important pour une portion non négligeable des utilisateurs.</p>
#     <p><strong>Last_order_channel :</strong> En ce qui concerne le dernier achat réalisé par les clients, l'application Android demeure dominante avec 34 %. Cependant, on note une forte présence du canal Offline, qui représente 33 % des transactions. Cela pourrait indiquer que de nombreux clients effectuent un premier achat en ligne, mais se tournent vers un achat en magasin physique pour leurs transactions ultérieures. Ce comportement suggère une complémentarité entre les canaux en ligne et hors ligne, où les clients alternent entre ces deux modes d'achat. En revanche, les autres plateformes telles que les applications Mobile et iOS sont toujours utilisées, tandis que le canal Desktop reste le moins privilégié pour les achats récents.</p>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Profil de la Clientèle</h3>
#     <p>
#         Les clients de FLO montrent une nette préférence pour les canaux mobiles, en particulier les applications Android, qui représentent près de 48 % des achats effectués. Cela met en évidence l'importance des plateformes mobiles dans les comportements d'achat des clients. Les applications iOS et Mobile suivent de près, confirmant la tendance dominante des systèmes téléphoniques comme principaux points d'interaction avec la marque.
#     </p>
#     <p>
#         En revanche, le canal Desktop, bien que moins utilisé, représente tout de même environ 14 % des transactions, suggérant que certains clients continuent de privilégier les achats sur ordinateur. Ce canal reste donc pertinent, notamment pour des segments de clients spécifiques qui pourraient préférer une interface plus traditionnelle pour naviguer et acheter.
#     </p>
#         Lorsqu'on s'intéresse au dernier achat effectué, nous remarquons un comportement intéressant : même si l'application Android reste la plateforme dominante (34 % des derniers achats), un changement significatif vers les achats en magasin physique (Offline) se dessine avec 33 % des transactions. Cela suggère une transition potentielle où les clients initient leurs achats en ligne pour ensuite finaliser leurs achats en présentiel. Cette alternance entre canaux en ligne et hors ligne indique une complémentarité dans l'expérience d'achat, où les clients utilisent divers canaux selon leurs besoins et préférences.
#         Ainsi, le profil des clients de FLO révèle une prédominance des canaux mobiles, accompagnée d'une utilisation stratégique des canaux hors ligne pour les achats ultérieurs, ce qui souligne l'importance d'une approche omnicanal dans les stratégies de marketing et de vente.
#     </p>
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Visualisation de nos variables de comptage</h3>
#     <p>

# %%
# Liste des variables continues en français
variables = ['order_num_total_ever_online', 'order_num_total_ever_offline', 
             'customer_value_total_ever_offline', 'customer_value_total_ever_online']

# Taille de la figure pour l'affichage des graphiques
plt.figure(figsize=(14, 10))

# Parcours des variables et création des histogrammes/densités
for i, var in enumerate(variables):
    plt.subplot(2, 2, i + 1)  # Création d'une grille 2x2 pour les graphiques
    sns.histplot(Data_CRM[var], kde=True, color="skyblue")  # Histogramme avec courbe de densité (kde)
    plt.title(f'Distribution de {var}')
    plt.xlabel(var)
    plt.ylabel('Fréquence')

# Ajustement de l'espacement entre les graphiques
plt.tight_layout()
plt.show()

# %%
# Taille de la figure pour l'affichage des graphiques
plt.figure(figsize=(14, 10))

# Parcours des variables et création des box plots
for i, var in enumerate(variables):
    plt.subplot(2, 2, i + 1)  # Création d'une grille 2x2 pour les graphiques
    sns.boxplot(y=Data_CRM[var], color="skyblue")  # Création d'un box plot
    plt.title(f'Box Plot de {var}')
    plt.ylabel(var)

# Ajustement de l'espacement entre les graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Comportements en termes de dépense en achats</h3>
#     <p><strong>Forte asymétrie à droite :</strong> Les distributions sont fortement asymétriques avec une queue à droite (right-skewed). Cela signifie que la plupart des clients effectuent un nombre relativement faible de commandes, que ce soit en ligne ou hors ligne.</p>
#     <p><strong>Valeurs extrêmes (Outliers) </strong> Les queues longues dans les deux distributions suggèrent la présence de valeurs extrêmes (outliers), représentant des clients avec un nombre exceptionnellement élevé de commandes par rapport à la majorité. Ces clients peuvent représenter une classe très spécifique, par exemple des clients très fidèles ou des entreprises réalisant des achats massifs.</p>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Profil des acheteurs en termes de dépenses</h3>
#     <p>
#         Les données révèlent une base de clients très segmentée avec une majorité de clients modérés et une petite portion de clients VIP ou "super utilisateurs". Il serait judicieux pour FLO d'adopter des stratégies de marketing différenciées en fonction de ces profils : des actions ciblées pour les clients VIP afin de maximiser leur fidélité et des offres incitatives pour les clients réguliers afin de les encourager à augmenter leur volume d'achats.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Création de nouvelles variables</h1></center>
# <hr style="border-width:2px;border-color:#75DFC1">
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">📊 Introduction</h3>
#     <p>
#         Afin d'enrichir notre analyse, nous avons créé de nouvelles variables qui apportent des informations supplémentaires sur les comportements d'achat de nos clients. Ces variables sont dérivées des colonnes de dates, telles que les dates des premières et dernières commandes, ainsi que les commandes effectuées en ligne et hors ligne. Cela nous permet de mieux comprendre l'engagement des clients et leurs préférences en termes de canaux.
#     </p>
#     <h4>🕒 Durée de la Relation Client (Customer Lifetime)</h4>
#     <p>
#         <strong>Variable :</strong> <code>customer_lifetime</code> <br>
#         <strong>Description :</strong> Cette variable mesure la durée totale (en jours) entre la première commande du client et sa dernière commande, indiquant depuis combien de temps le client est actif avec l'entreprise. Elle permet d'évaluer la fidélité des clients au fil du temps.
#     </p>
#     <h4>🔄 Temps Moyen entre les Commandes (Time Between Orders)</h4>
#     <p>
#         <strong>Variable :</strong> <code>time_between_orders</code> <br>
#         <strong>Description :</strong> Cette variable représente le temps moyen (en jours) entre chaque commande effectuée par le client. Elle est calculée en divisant la durée de la relation client par le nombre total de commandes. Elle aide à comprendre la fréquence d'achat du client.
#     </p>
#     <h4>📅 Récence en Ligne vs Hors Ligne (Online vs Offline Recency)</h4>
#     <p>
#         <strong>Variable :</strong> <code>online_vs_offline_recency</code> <br>
#         <strong>Description :</strong> Cette variable compare la récence des commandes en ligne par rapport aux commandes hors ligne en calculant la différence en jours entre la dernière commande en ligne et la dernière commande hors ligne. Elle permet d'analyser quel canal est privilégié par le client dans ses achats récents.
#     </p>
#     <h4>⚖️ Fréquence des Commandes en Ligne vs Hors Ligne (Online vs Offline Order Frequency)</h4>
#     <p>
#         <strong>Variable :</strong> <code>online_vs_offline_order_frequency</code> <br>
#         <strong>Description :</strong> Cette variable exprime le ratio entre le nombre total de commandes en ligne et hors ligne. Elle permet de déterminer si un client préfère commander en ligne ou hors ligne et d'évaluer ses habitudes d'achat par canal.
#     </p>
#     <p>
#         Ces nouvelles variables sont cruciales pour mieux comprendre les habitudes d'achat de nos clients et pour adapter les stratégies de marketing en fonction de leurs préférences. Elles nous permettront d'identifier des segments spécifiques de clients, tels que ceux qui sont plus fidèles à un canal d'achat, et de personnaliser les campagnes marketing en conséquence.
#     </p>
# </div>

# %%
# 1. Création de la variable 'customer_lifetime'
# Durée de la relation client : nombre de jours entre la première commande et la dernière commande
Data_CRM['customer_lifetime'] = (Data_CRM['last_order_date'] - Data_CRM['first_order_date']).dt.days

# 2. Création de la variable 'time_between_orders'
# Temps moyen entre les commandes
# On utilise le nombre total de commandes (en ligne + hors ligne) pour obtenir la fréquence moyenne d'achat
Data_CRM['total_orders'] = Data_CRM['order_num_total_ever_online'] + Data_CRM['order_num_total_ever_offline']
# Éviter la division par 0 en vérifiant que total_orders n'est pas nul
Data_CRM['time_between_orders'] = Data_CRM['customer_lifetime'] / Data_CRM['total_orders']
Data_CRM['time_between_orders'] = Data_CRM['time_between_orders'].replace([float('inf'), -float('inf')], None)

# 3. Création de la variable 'online_vs_offline_recency'
# Différence en jours entre la dernière commande en ligne et la dernière commande hors ligne
Data_CRM['online_vs_offline_recency'] = (Data_CRM['last_order_date_online'] - Data_CRM['last_order_date_offline']).dt.days

# 4. Création de la variable 'online_vs_offline_order_frequency'
# Ratio entre le nombre total de commandes en ligne et hors ligne
Data_CRM['online_vs_offline_order_frequency'] = Data_CRM['order_num_total_ever_online'] / Data_CRM['order_num_total_ever_offline']

Data_CRM[['master_id','customer_lifetime','time_between_orders','online_vs_offline_recency','online_vs_offline_order_frequency']].head()
# Out:
#                               master_id  customer_lifetime  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f                119
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f               1469
# 2  69b69676-1a40-11ea-941b-000d3a38a36f                366
# 3  1854e56c-491f-11eb-806e-000d3a38a36f                 11
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f                582
#
#    time_between_orders  online_vs_offline_recency  \
# 0            23.800000                         -5
# 1            69.952381                        403
# 2            73.200000                        362
# 3             5.500000                         11
# 4           291.000000                        582
#
#    online_vs_offline_order_frequency
# 0                                4.0
# 1                                9.5
# 2                                1.5
# 3                                1.0
# 4                                1.0

# %%
Data_CRM.dtypes
# Out:
# master_id                                    object
# order_channel                                object
# last_order_channel                           object
# first_order_date                     datetime64[ns]
# last_order_date                      datetime64[ns]
# last_order_date_online               datetime64[ns]
# last_order_date_offline              datetime64[ns]
# order_num_total_ever_online                 float64
# order_num_total_ever_offline                float64
# customer_value_total_ever_offline           float64
# customer_value_total_ever_online            float64
# interested_in_categories_12                  object
# customer_lifetime                             int64
# total_orders                                float64
# time_between_orders                         float64
# online_vs_offline_recency                     int64
# online_vs_offline_order_frequency           float64
# dtype: object

# %%
# Liste des variables continues en français
variables_construites = ['customer_lifetime', 'time_between_orders', 'online_vs_offline_recency', 'online_vs_offline_order_frequency']

# Taille de la figure pour l'affichage des graphiques
plt.figure(figsize=(14, 10))

# Parcours des variables et création des histogrammes/densités
for i, var in enumerate(variables_construites):
    plt.subplot(2, 2, i + 1)  # Création d'une grille 2x2 pour les graphiques
    sns.histplot(Data_CRM[var], kde=True, color="skyblue")  # Histogramme avec courbe de densité (kde)
    plt.title(f'Distribution de {var}')
    plt.xlabel(var)
    plt.ylabel('Fréquence')

# Ajustement de l'espacement entre les graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Comportements en termes de Variables Construites</h3>
#     <p><strong>Durée de la Relation Client :</strong> La majorité des clients ont une durée de vie relativement courte, autour de 0 à 500 jours, avec une décroissance rapide. Cependant, un petit groupe de clients se démarque par une relation beaucoup plus longue (jusqu'à près de 3000 jours). Cela indique qu'un petit segment de clients très fidèles reste actif avec l'entreprise sur une longue période.</p>
#     <p><strong>Temps Moyen entre les Commandes :</strong> La plupart des clients passent des commandes à des intervalles courts (0 à 200 jours). Plus l'intervalle entre les commandes augmente, moins cela devient fréquent. Cela montre que la majorité des clients effectuent des achats à un rythme relativement régulier, tandis que peu d'entre eux laissent de longs intervalles entre leurs commandes.</p>
#     <p><strong>Récence en Ligne vs Hors Ligne :</strong> La distribution montre une concentration autour de 0 à 500 jours, suggérant que pour la majorité des clients, leurs commandes en ligne et hors ligne sont récentes et relativement proches dans le temps. Les valeurs extrêmes dans les deux directions révèlent que certains clients privilégient l'un des canaux de façon beaucoup plus récente par rapport à l'autre.</p>
#     <p><strong>Fréquence des Commandes en Ligne vs Hors Ligne :</strong> La majorité des clients ont un ratio de fréquence des commandes en ligne par rapport aux commandes hors ligne très faible, avec un pic autour de zéro. Cela indique que la plupart des clients préfèrent effectuer leurs achats hors ligne. Cependant, un sous-ensemble de clients présente des ratios élevés, indiquant une forte préférence pour les achats en ligne.</p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Analyse Bivariée et Multivariée</h1></center>
# <hr style="border-width:2px;border-color:#75DFC1">
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">🔍 Introduction</h3>
#     <p>
#         Afin de mieux comprendre les comportements d'achat de nos clients et d'identifier des segments pertinents, nous effectuons des analyses bivariées et multivariées sur nos données. Ces analyses nous permettent d'explorer les relations entre différentes variables et d'enrichir les modèles de clustering qui seront mis en place.
#     </p>
#     <h4>📊 Relation entre Durée de la Relation Client et Nombre Total de Commandes</h4>
#     <p>
#         <strong>Axe d'analyse :</strong> <code>customer_lifetime</code> vs <code>total_orders</code> <br>
#         <strong>Description :</strong> Nous analysons la relation entre la durée de la relation client (en jours) et le nombre total de commandes effectuées (en ligne et hors ligne). Cette analyse peut révéler des différences entre des clients fidèles avec un grand nombre de commandes et des clients occasionnels.
#     </p>
#     <h4>⏱️ Temps Moyen entre Commandes et Fréquence d'Achat</h4>
#     <p>
#         <strong>Axe d'analyse :</strong> <code>time_between_orders</code> vs <code>total_orders</code> <br>
#         <strong>Description :</strong> Cet axe permet d'évaluer la fréquence des achats en examinant le temps moyen entre les commandes et le nombre total de commandes. Cette analyse est essentielle pour identifier les clients actifs qui effectuent des achats à des intervalles réguliers par rapport aux clients moins actifs.
#     </p>
#     <h4>🌐 Comparaison des Comportements en Ligne et Hors Ligne</h4>
#     <p>
#         <strong>Axe d'analyse :</strong> <code>online_vs_offline_recency</code> vs <code>online_vs_offline_order_frequency</code> <br>
#         <strong>Description :</strong> Cette analyse compare la récence des commandes en ligne et hors ligne avec la fréquence des commandes dans chaque canal. Elle permet de comprendre les préférences des clients en matière de canaux et d'identifier ceux qui privilégient les achats en ligne ou hors ligne.
#     </p>
#     <h4>💰 Valeur Client et Récence</h4>
#     <p>
#         <strong>Axe d'analyse :</strong> <code>recency</code> vs <code>customer_value_total_ever_online</code> et <code>customer_value_total_ever_offline</code> <br>
#         <strong>Description :</strong> Cet axe explore la relation entre la récence des achats et la valeur totale dépensée en ligne et hors ligne. Il est crucial pour identifier les clients à forte valeur et comprendre comment ils interagissent avec les différents canaux d'achat.
#     </p>
#     <p>
#         Ces analyses bivariées et multivariées fournissent des insights importants sur les comportements des clients, facilitant la mise en place de modèles de clustering plus précis. Cela nous aidera à créer des segments de clients actionnables, en vue d'adapter les stratégies de marketing et d'améliorer l'engagement des clients.
#     </p>
# </div>

# %%
# Création d'une figure avec une grille de 2 lignes et 2 colonnes
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# 1. Relation entre la durée de la relation client et le nombre total de commandes
sns.scatterplot(x='customer_lifetime', y='total_orders', data=Data_CRM, hue='customer_lifetime', palette="viridis", ax=axes[0, 0])
axes[0, 0].set_title('Relation entre la durée de la relation client et le nombre total de commandes')
axes[0, 0].set_xlabel('Durée de la relation client (jours)')
axes[0, 0].set_ylabel('Nombre total de commandes')

# 2. Temps moyen entre les commandes et le nombre total de commandes
sns.scatterplot(x='time_between_orders', y='total_orders', data=Data_CRM, hue='total_orders', palette="coolwarm", ax=axes[0, 1])
axes[0, 1].set_title('Temps moyen entre les commandes et nombre total de commandes')
axes[0, 1].set_xlabel('Temps moyen entre commandes (jours)')
axes[0, 1].set_ylabel('Nombre total de commandes')

# 3. Comparaison de la récence en ligne vs hors ligne et la fréquence des commandes
sns.scatterplot(x='online_vs_offline_recency', y='online_vs_offline_order_frequency', data=Data_CRM, hue='online_vs_offline_order_frequency', palette="plasma", ax=axes[1, 0])
axes[1, 0].set_title('Comparaison de la récence en ligne vs hors ligne et fréquence des commandes')
axes[1, 0].set_xlabel('Différence de récence (en jours)')
axes[1, 0].set_ylabel('Fréquence des commandes en ligne vs hors ligne')

# 4. Valeur client (online vs offline) et récence
sns.scatterplot(x='online_vs_offline_recency', y='customer_value_total_ever_online', data=Data_CRM, label='En ligne', color='blue', ax=axes[1, 1])
sns.scatterplot(x='online_vs_offline_recency', y='customer_value_total_ever_offline', data=Data_CRM, label='Hors ligne', color='red', ax=axes[1, 1])
axes[1, 1].set_title('Relation entre la récence et la valeur client (online/offline)')
axes[1, 1].set_xlabel('Récence (jours)')
axes[1, 1].set_ylabel('Valeur client totale')
axes[1, 1].legend()

# Ajustement de l'espace entre les sous-graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="color: #75DFC1;">⏱️ Durée de la relation client et le Nombre Total de Commandes</h3>
# <p>
#     <strong>Description :</strong> Ce graphique montre la relation entre le temps moyen entre les commandes (<code>time_between_orders</code>) et le nombre total de commandes (<code>total_orders</code>). <br>
#     <strong>Analyse :</strong> cette analyse révèle que le nombre de commandes reste relativement constant pour la majorité des clients, quelle que soit la durée de leur relation avec l'entreprise. Cependant, il existe des outliers intéressants, qui montrent que certains clients peuvent être extrêmement actifs, que leur relation soit courte ou longue. Le temps écoulé entre la première et la dernière commande joue un rôle important dans la distinction des comportements, offrant des pistes pour une segmentation fine et des stratégies de fidélisation adaptées.
# </p>
#
# <h3 style="color: #75DFC1;">⏱️ Temps moyen entre les commandes et le Nombre Total de Commandes</h3>
# <p>
#     <strong>Description :</strong> Ce graphique compare le temps moyen entre les commandes (<code>time_between_orders</code>) et le nombre de commandes (<code>total_orders</code>). <br>
#     <strong>Analyse :</strong> Les clients qui commandent plus fréquemment (avec des temps moyens plus courts entre les commandes) génèrent un nombre total de commandes plus élevé. À mesure que les intervalles entre les commandes augmentent, on observe une baisse significative du nombre de commandes. Cependant, les clients ayant des temps moyens très élevés maintiennent un nombre de commandes faible mais constant, ce qui souligne leur potentiel pour des campagnes de réengagement et de fidélisation ciblées.
# </p>
#
# <h3 style="color: #75DFC1;">📊 Comparaison de la Récence en Ligne vs Hors Ligne et Fréquence des Commandes</h3>
# <p>
#     <strong>Description :</strong> Ce graphique compare la récence entre les commandes en ligne et hors ligne (<code>online_vs_offline_recency</code>) et la fréquence des commandes (<code>online_vs_offline_order_frequency</code>). <br>
#     <strong>Analyse :</strong> Nous remarquons que les clients avec une faible différence de récence (en dessous de 0) ont tendance à commander moins fréquemment. Cependant, certains clients avec une forte différence de récence (jusqu'à 1000 jours) montrent des fréquences de commande beaucoup plus élevées, indiquant qu'ils privilégient fortement un canal par rapport à l'autre (soit en ligne, soit hors ligne) pour effectuer leurs commandes.
# </p>
#
# <h3 style="color: #75DFC1;">💰 Relation entre la Récence et la Valeur Client (Online/Offline)</h3>
# <p>
#     <strong>Description :</strong> Ce graphique montre la relation entre la récence (<code>online_vs_offline_recency</code>) et la valeur totale des clients (<code>customer_value_total_ever_online</code> et <code>customer_value_total_ever_offline</code>). <br>
#     <strong>Analyse :</strong> Nous observons que les clients avec une récence proche de 0 (clients très récents) présentent des valeurs plus élevées, principalement en ligne (points bleus). Cela indique que les clients récents ont tendance à dépenser davantage en ligne par rapport à hors ligne. De plus, les clients avec une forte récence (n'ayant pas effectué de commande depuis longtemps) tendent à avoir une valeur client plus faible.
# </p>

# %%
# Création d'une figure avec une grille de 2 lignes et 2 colonnes
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# 1. Durée de la relation client par canal de commande (order_channel)
sns.boxplot(x='order_channel', y='customer_lifetime', data=Data_CRM, palette='Set3', ax=axes[0, 0])
axes[0, 0].set_title('Durée de la Relation Client par Canal de Commande')
axes[0, 0].set_xlabel('Canal de Commande')
axes[0, 0].set_ylabel('Durée de la Relation Client (jours)')
axes[0, 0].tick_params(axis='x', rotation=45)

# 2. Fréquence des commandes par canal de commande (order_channel)
sns.boxplot(x='order_channel', y='total_orders', data=Data_CRM, palette='Set2', ax=axes[0, 1])
axes[0, 1].set_title('Fréquence des Commandes par Canal de Commande')
axes[0, 1].set_xlabel('Canal de Commande')
axes[0, 1].set_ylabel('Nombre Total de Commandes')
axes[0, 1].tick_params(axis='x', rotation=45)

# 3. Valeur client par dernier canal utilisé (last_order_channel)
sns.boxplot(x='last_order_channel', y='customer_value_total_ever_online', data=Data_CRM, palette='Set1', ax=axes[1, 0])
axes[1, 0].set_title('Valeur Client (Online) par Dernier Canal Utilisé')
axes[1, 0].set_xlabel('Dernier Canal Utilisé')
axes[1, 0].set_ylabel('Valeur Client Totale (Online)')
axes[1, 0].tick_params(axis='x', rotation=45)

# 4. Récence des commandes par dernier canal utilisé (last_order_channel)
sns.boxplot(x='last_order_channel', y='online_vs_offline_recency', data=Data_CRM, palette='coolwarm', ax=axes[1, 1])
axes[1, 1].set_title('Récence des Commandes par Dernier Canal Utilisé')
axes[1, 1].set_xlabel('Dernier Canal Utilisé')
axes[1, 1].set_ylabel('Récence (jours)')
axes[1, 1].tick_params(axis='x', rotation=45)

# Ajustement de l'espacement entre les sous-graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="color: #75DFC1;">⏱️ Fréquence des Commandes par Canal de Commande</h3>
# <p>
#     <strong>Description :</strong> Ce box plot montre le nombre total de commandes effectuées par les clients (<code>total_orders</code>) en fonction du canal de commande. <br>
#     <strong>Analyse :</strong> Les utilisateurs de l'Android App semblent passer plus de commandes en moyenne par rapport aux autres canaux, comme le Desktop ou les autres applications mobiles. Cependant, les autres canaux montrent moins de commandes en général. Cette différence pourrait suggérer que les utilisateurs d'Android sont plus enclins à utiliser leur application pour commander régulièrement, tandis que les autres canaux semblent générer moins d'interactions en termes de commandes.
# </p>
#
# <h3 style="color: #75DFC1;">💰 Valeur Client (Online) par Dernier Canal Utilisé</h3>
# <p>
#     <strong>Description :</strong> Ce box plot montre la distribution de la valeur client totale en ligne (<code>customer_value_total_ever_online</code>) par rapport au dernier canal utilisé pour effectuer un achat (<code>last_order_channel</code>). <br>
#     <strong>Analyse :</strong> La plupart des canaux ont une médiane de valeur client relativement basse, mais certains canaux, notamment l'Android App et le Desktop, montrent des clients qui dépensent significativement plus en ligne. Cela pourrait indiquer que ces canaux sont plus efficaces pour générer des dépenses élevées, avec des outliers significatifs atteignant des valeurs très élevées, notamment via les canaux Desktop et Android App.
# </p>
#
# <h3 style="color: #75DFC1;">📅 Récence des Commandes par Dernier Canal Utilisé</h3>
# <p>
#     <strong>Description :</strong> Ce box plot montre la récence des commandes (<code>recency</code>) en fonction du dernier canal utilisé. <br>
#     <strong>Analyse :</strong> Les clients ayant effectué leur dernier achat hors ligne (<code>Offline</code>) ont tendance à avoir une récence beaucoup plus élevée (donc des achats plus anciens), comparé aux clients ayant utilisé des canaux en ligne ou des applications mobiles, qui présentent des récences plus faibles. Cela peut indiquer que les clients hors ligne sont moins récurrents dans leurs achats, tandis que les utilisateurs des canaux numériques sont plus récents dans leurs interactions avec l'entreprise.
# </p>

# %% [markdown]
# <br/>
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>⚙️ Approches de Clustering</h1></center>
# <hr style="border-width:2px;border-color:#75DFC1">
# <p>
#     Une fois les tests statistiques validés, plusieurs approches de clustering seront expérimentées pour segmenter nos clients de manière optimale. Nous testerons notamment :
# </p>
# <ul>
#     <li><strong>K-Means Clustering :</strong> Cette méthode classique de clustering partitionne les données en fonction de leur proximité aux centres de clusters (centroids). Elle est rapide et efficace pour les grandes bases de données.</li>
#     <li><strong>Clustering Hiérarchique :</strong> Cette approche permet de créer des clusters sous forme d'arborescences (dendrogrammes) et est utile pour visualiser les relations hiérarchiques entre les clients.</li>
#     <li><strong>DBSCAN :</strong> Une méthode plus flexible pour identifier des clusters de formes variées et qui est robuste face aux outliers.</li>
# </ul>
#
# <p>
#     Cette phase de tests statistiques et d'exploration des approches de clustering est cruciale pour garantir la robustesse de nos résultats et pour déterminer les segments de clientèle de manière précise. Cela nous permettra de mieux comprendre les comportements des clients et d'adapter nos stratégies marketing en fonction des groupes identifiés.
# </p>

# %%
# Importer une fonction spécifique depuis Hoopkins_test.py
from Models_and_test.Hoopkins_test import hopkins

from sklearn.neighbors import NearestNeighbors
from random import sample
import numpy as np
from random import uniform
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
import pandas as pd
from random import sample, uniform

def hopkins(X):
    d = X.shape[1]  # Nombre de dimensions
    n = len(X)  # Nombre d'échantillons
    m = int(0.3 * n)  # Proportion d'échantillons pour le test
    
    # Initialiser NearestNeighbors
    nbrs = NearestNeighbors(n_neighbors=2).fit(X)
    
    # Variables pour stocker les distances
    ujd = []
    wjd = []
    
    # Générer des points aléatoires dans l'espace des données
    for j in range(m):
        # Générer un point aléatoire dans les limites des colonnes (dimensions)
        random_point = [uniform(np.min(X[:,i]), np.max(X[:,i])) for i in range(d)]
        
        # Calculer les distances des points aléatoires
        u_dist, _ = nbrs.kneighbors([random_point], n_neighbors=2, return_distance=True)
        ujd.append(u_dist[0][1])
        
        # Choisir un point réel aléatoire dans X et calculer la distance
        w_dist, _ = nbrs.kneighbors(X[np.random.randint(0, n)].reshape(1, -1), n_neighbors=2, return_distance=True)
        wjd.append(w_dist[0][1])
    
    # Calcul de la statistique de Hopkins
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    
    return H

# %%
Col_int=['customer_lifetime', 'time_between_orders', 'online_vs_offline_recency', 'online_vs_offline_order_frequency','customer_lifetime', 'time_between_orders', 'online_vs_offline_recency', 'online_vs_offline_order_frequency','order_num_total_ever_online', 'order_num_total_ever_offline', 
             'customer_value_total_ever_offline', 'customer_value_total_ever_online']

scaler = StandardScaler()
Data_normalized = scaler.fit_transform(Data_CRM[Col_int])

# Lancement du test de Hopkins
hopkins_score = hopkins(Data_normalized)
print("Hopkins Statistic: ", hopkins_score)
# Out:
# Hopkins Statistic:  0.994230746488808

# %%
from sklearn.decomposition import PCA

# Étape 1: Standardisation des données
# Étape déja faite précédemment

# Étape 2: Appliquer l'ACP
pca = PCA(n_components=2)  # Réduire à 2 dimensions
Data_pca = pca.fit_transform(Data_normalized)

# Étape 3: Ajouter les nouvelles dimensions à votre DataFrame
Data_CRM['PCA1'] = Data_pca[:, 0]  # Première composante principale
Data_CRM['PCA2'] = Data_pca[:, 1]  # Deuxième composante principale

# Afficher les deux premières dimensions de l'ACP
print(Data_CRM[['PCA1', 'PCA2']].head())
# Out:
#        PCA1      PCA2
# 0  1.143695 -1.306676
# 1  4.872019  2.499209
# 2  0.356263 -1.409084
# 3 -0.183934 -2.252002
# 4 -0.593931 -0.297875

# %%
# Tracer les deux premières composantes principales dans un nuage de points
plt.figure(figsize=(8, 6))
plt.scatter(Data_CRM['PCA1'], Data_CRM['PCA2'], c='blue', edgecolor='k', s=50)
plt.title('ACP: Projection des Données sur les Deux Premières Composantes')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.grid(True)
plt.show()

# %% [markdown]
# <br/> <hr style="border-width:2px;border-color:#75DFC1"> <center><h1>📊 Modélisation et Clustering</h1></center> <hr style="border-width:2px;border-color:#75DFC1">
#
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
# <h3 style="color: #75DFC1;">📊 Implémentation du Modèle de Clustering</h3>
#
# <p> Dans cette section, nous allons implémenter plusieurs approches de clustering afin d'explorer les différentes manières de segmenter nos données. Chaque méthode a ses spécificités et son intérêt, et en les comparant, nous pourrons identifier celle qui offre la meilleure segmentation. Nous allons tester les méthodes suivantes : </p>
# <p> <strong>K-Means :</strong> Algorithme de clustering très populaire qui partitionne les données en fonction de la distance euclidienne aux centres de clusters. Son principal intérêt réside dans sa simplicité et son efficacité, mais il est limité par sa sensibilité aux outliers et ne fonctionne bien que pour des clusters de forme sphérique. </p>
# <p> <strong>K-Prototypes :</strong> Extension du K-Means permettant de gérer à la fois des variables numériques et catégorielles. Il est particulièrement utile lorsque l'on travaille avec des données mixtes, ce qui est souvent le cas dans les analyses CRM. </p> <p> <strong>K-Mix :</strong> Une autre approche adaptée aux données contenant des variables continues et discrètes. K-Mix utilise des mélanges de gaussiennes et est capable de modéliser des données plus complexes avec des distributions plus variées. </p>
# <p> <strong>Agglomerative Clustering :</strong> Technique de clustering hiérarchique qui construit une hiérarchie de clusters en fusionnant successivement les plus proches. Ce type de clustering est intéressant car il permet de visualiser les relations hiérarchiques entre les clusters, mais il est souvent plus lent que K-Means pour de grandes quantités de données. </p>
# <p> L'objectif de cette étape est de tester et de comparer ces différentes approches afin de trouver celle qui segmente le mieux nos données clients en fonction des caractéristiques disponibles. Cette analyse nous permettra d'exploiter au mieux les résultats du clustering pour ajuster nos stratégies marketing. </p>
#
# </div>

# %% [markdown]
# <br/>
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
# <h3 style="color: #75DFC1;">🔢  Méthodologie pour Sélectionner le Nombre de Clusters</h3>
# <p> La détermination du nombre optimal de clusters est une étape clé dans la mise en place de nos modèles de clustering. Pour identifier le nombre de clusters le plus adapté à nos données, nous nous appuyons sur deux méthodes complémentaires : la méthode du coude et le score de silhouette. Ces approches permettent de trouver un équilibre entre la simplicité de la segmentation et la qualité des regroupements. </p>
#
# <p> <strong>Méthode du Coude :</strong> Cette méthode consiste à évaluer l'évolution de l'<strong>inertie</strong> (somme des distances au carré des points par rapport à leur centre de cluster) en fonction du nombre de clusters. L'inertie diminue lorsque le nombre de clusters augmente, mais à partir d'un certain point, le gain de réduction devient marginal. Le "coude" de la courbe représente ce point, où une augmentation supplémentaire du nombre de clusters n'apporte plus de réelle amélioration de la segmentation. </p>
#
# <p> <strong>Score de Silhouette :</strong> Ce score évalue la qualité de la segmentation en mesurant à quel point les points sont proches de leur propre cluster par rapport aux autres clusters. Il prend des valeurs entre -1 et 1, où un score proche de 1 indique des clusters bien distincts et compacts. En comparant les scores de silhouette pour différents nombres de clusters, nous pouvons identifier celui qui offre le meilleur compromis entre séparation des clusters et compacité. </p>
#
# <p> Ces deux méthodologies sont appliquées conjointement pour valider le choix du nombre de clusters. La méthode du coude nous aide à identifier le point à partir duquel l'ajout de clusters devient moins pertinent, tandis que le score de silhouette nous permet de vérifier la cohérence et la qualité de la segmentation choisie. </p>
#
# </div>

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


# Liste pour stocker les résultats
results = []

# Itération sur le nombre de clusters de 1 à 10
for n_clusters in range(1, 11):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)  # Fixer la seed pour la reproductibilité
    kmeans.fit(Data_normalized)
    
    # Calculer l'inertie (distorsion) : somme des distances au carré
    inertia = kmeans.inertia_
    
    # Calculer le score de silhouette uniquement si n_clusters > 1
    if n_clusters > 1:
        silhouette_avg = silhouette_score(Data_normalized, kmeans.labels_)
    else:
        silhouette_avg = np.nan  # Pas de score de silhouette pour un seul cluster
    
    # Ajouter les résultats à la liste
    results.append({
        'n_clusters': n_clusters,
        'inertia': inertia,
        'silhouette_score': silhouette_avg
    })

# Convertir les résultats en DataFrame
df_results = pd.DataFrame(results)

# Afficher le DataFrame des résultats
print(df_results)
# Out:
#    n_clusters        inertia  silhouette_score
# 0           1  239340.000000               NaN
# 1           2  185123.029657          0.508157
# 2           3  147698.381912          0.507176
# 3           4  132195.938578          0.227378
# 4           5  118914.321943          0.232003
# 5           6  106303.422229          0.233831
# 6           7   96432.987052          0.239179
# 7           8   87767.228232          0.245520
# 8           9   77609.693400          0.248368
# 9          10   70047.926077          0.269839

# %%
# Visualiser l'inertie
plt.figure(figsize=(10, 5))
plt.plot(df_results['n_clusters'], df_results['inertia'], marker='o', label='Inertia')
plt.title('Inertia en fonction du nombre de clusters')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# Visualiser le score de silhouette
plt.figure(figsize=(10, 5))
plt.plot(df_results['n_clusters'], df_results['silhouette_score'], marker='o', label='Silhouette Score', color='green')
plt.title('Score de silhouette en fonction du nombre de clusters')
plt.xlabel('Nombre de clusters')
plt.ylabel('Score de silhouette')
plt.grid(True)
plt.show()

# %% [markdown]
# <br/> <hr style="border-width:2px;border-color:#75DFC1"> <center><h1>📊 Implémentation du Modèle K-means</h1></center> <hr style="border-width:2px;border-color:#75DFC1"> <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;"> <h3 style="color: #75DFC1;">⚙️ Mise en Place du Modèle K-means</h3> <p> Après avoir déterminé le nombre optimal de clusters, nous mettons en place un modèle K-means pour segmenter notre base de données. L'algorithme de K-means regroupe les individus en minimisant la distance intra-cluster, ce qui permet de former des groupes compacts et distincts. </p> <p> Nous appliquons le modèle sur notre base de données standardisée, puis nous attribuons chaque individu à un cluster spécifique. Cela nous permettra de mieux comprendre les caractéristiques de chaque groupe et de développer des stratégies adaptées pour chaque segment de clients. </p> </div>

# %%
# Choisissez le nombre optimal de clusters trouvé précédemment
n_clusters_optimal = 3  # Remplacez par le nombre de clusters choisi

# Instanciation et ajustement du modèle K-means
kmeans = KMeans(n_clusters=n_clusters_optimal, random_state=42)  # Fixer la seed pour la reproductibilité
kmeans.fit(Data_normalized)

# Attribution des clusters à chaque individu
# 'labels_' contient les labels de chaque individu après le clustering
Data_CRM['cluster_Kmeans'] = kmeans.labels_

# Afficher les premières lignes avec l'attribution des clusters
print(Data_CRM[['cluster_Kmeans']].head())
# Out:
#    cluster_Kmeans
# 0               2
# 1               0
# 2               2
# 3               2
# 4               2

# %%
# Liste des variables continues que l'on souhaite visualiser
variables_continues = ['customer_lifetime', 'time_between_orders', 
                       'online_vs_offline_recency', 'online_vs_offline_order_frequency']

# Créer des box plots pour chaque variable continue, groupée par les clusters
plt.figure(figsize=(14, 10))

for i, var in enumerate(variables_continues, 1):
    plt.subplot(2, 2, i)  # Organiser les plots sur une grille 2x2
    sns.boxplot(x='cluster_Kmeans', y=var, data=Data_CRM, palette='viridis')
    plt.title(f'Distribution de {var} par Cluster')
    plt.xlabel('Cluster')
    plt.ylabel(var)
    plt.grid(True)

# Ajuster l'espacement entre les graphiques pour éviter le chevauchement
plt.tight_layout()
plt.show()

# %%
# Supposons que les deux variables continues soient 'PCA1' et 'PCA2'
var_x = 'PCA1'
var_y = 'PCA2'

# Créer un scatter plot avec couleur en fonction du cluster
plt.figure(figsize=(10, 6))
sns.scatterplot(x=var_x, y=var_y, hue='cluster_Kmeans', data=Data_CRM, palette='viridis', s=60, alpha=0.8, edgecolor='k')

# Ajouter des titres et labels
plt.title(f'Relation entre {var_x} et {var_y} colorée par Cluster')
plt.xlabel(var_x)
plt.ylabel(var_y)
plt.grid(True)
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')  # Déplacer la légende à l'extérieur du plot

# Afficher le graphique
plt.tight_layout()
plt.show()

# %% [markdown]
# <br/> <hr style="border-width:2px;border-color:#75DFC1"> <center><h1>📊 Implémentation du Modèle K-Prototypes</h1></center> <hr style="border-width:2px;border-color:#75DFC1">
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;"> <h3 style="color: #75DFC1;">⚙️ Mise en Place du Modèle K-Prototypes</h3>
#
# <p> Le modèle <strong>K-Prototypes</strong> est une extension de l'algorithme K-means, conçu pour traiter à la fois des variables numériques et des variables catégorielles. Il permet de segmenter les données mixtes en combinant la distance euclidienne pour les variables continues et la distance de correspondance (matching) pour les variables qualitatives. </p>
# <p> Dans cette section, nous spécifions les variables continues et les variables catégorielles, ainsi que le nombre optimal de clusters déterminé précédemment. Le modèle K-Prototypes est ensuite appliqué pour regrouper les individus, en tenant compte de la nature des données. </p>
#
# <p> L'algorithme K-Prototypes est particulièrement utile pour les analyses CRM où les informations sur les clients comprennent des caractéristiques à la fois quantitatives (par exemple, le montant total des achats) et qualitatives (par exemple, le canal de commande préféré). </p>
#
# </div>

# %%
# pip install kmodes

# %%
from kmodes.kprototypes import KPrototypes

# Supposons que Data_CRM soit votre DataFrame d'origine contenant les données.
# Spécifiez les variables continues et les variables catégorielles.
variables_continues = ['customer_lifetime', 'time_between_orders', 'online_vs_offline_recency', 'online_vs_offline_order_frequency','customer_lifetime', 'time_between_orders', 'online_vs_offline_recency', 'online_vs_offline_order_frequency','order_num_total_ever_online', 'order_num_total_ever_offline', 
             'customer_value_total_ever_offline', 'customer_value_total_ever_online']
variables_categoriques = ['order_channel', 'last_order_channel']

# Sélection des données pour le clustering
data_kproto = Data_CRM[variables_continues + variables_categoriques]

# Remplacement des valeurs manquantes éventuelles (facultatif)
# data_kproto = data_kproto.fillna(0)

# Conversion des colonnes catégorielles en type 'object' pour K-Prototypes
for col in variables_categoriques:
    data_kproto[col] = data_kproto[col].astype(str)

# Définir le nombre de clusters
n_clusters_optimal = 3  # Remplacez par le nombre de clusters souhaité

# Instanciation et ajustement du modèle K-Prototypes
kproto = KPrototypes(n_clusters=n_clusters_optimal, random_state=42)
clusters = kproto.fit_predict(data_kproto, categorical=[data_kproto.columns.get_loc(col) for col in variables_categoriques])

# Ajouter les attributions de clusters à la DataFrame d'origine
Data_CRM['cluster_KPrototypes'] = clusters

# Afficher les premières lignes avec les attributions de clusters
print(Data_CRM[['cluster_KPrototypes'] + variables_continues + variables_categoriques].head())
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_19532\3109461601.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kproto[col] = data_kproto[col].astype(str)
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_19532\3109461601.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_kproto[col] = data_kproto[col].astype(str)
#    cluster_KPrototypes  customer_lifetime  time_between_orders  \
# 0                    1                119            23.800000
# ...

# %%
# Liste des variables continues que l'on souhaite visualiser
variables_continues = ['customer_lifetime', 'time_between_orders', 
                       'online_vs_offline_recency', 'online_vs_offline_order_frequency']

# Créer des box plots pour chaque variable continue, groupée par les clusters
plt.figure(figsize=(14, 10))

for i, var in enumerate(variables_continues, 1):
    plt.subplot(2, 2, i)  # Organiser les plots sur une grille 2x2
    sns.boxplot(x='cluster_KPrototypes', y=var, data=Data_CRM, palette='viridis')
    plt.title(f'Distribution de {var} par Cluster')
    plt.xlabel('Cluster')
    plt.ylabel(var)
    plt.grid(True)

# Ajuster l'espacement entre les graphiques pour éviter le chevauchement
plt.tight_layout()
plt.show()

# %%
# Supposons que les deux variables continues soient 'PCA1' et 'PCA2'
var_x = 'PCA1'
var_y = 'PCA2'

# Créer un scatter plot avec couleur en fonction du cluster
plt.figure(figsize=(10, 6))
sns.scatterplot(x=var_x, y=var_y, hue='cluster_KPrototypes', data=Data_CRM, palette='viridis', s=60, alpha=0.8, edgecolor='k')

# Ajouter des titres et labels
plt.title(f'Relation entre {var_x} et {var_y} colorée par Cluster')
plt.xlabel(var_x)
plt.ylabel(var_y)
plt.grid(True)
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')  # Déplacer la légende à l'extérieur du plot

# Afficher le graphique
plt.tight_layout()
plt.show()

# %%
Data_CRM
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <hr style="border-width:2px;border-color:#75DFC1">
#     <center><h1>Conclusion</h1></center>
#     <hr style="border-width:2px;border-color:#75DFC1">
#
# </div>
